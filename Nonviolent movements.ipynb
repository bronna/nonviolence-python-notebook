# %%
import pandas as pd

# %%
pd.set_option('precision', 5)

# %%
dataset = pd.read_stata("WCRWreplication.dta")

# %%
dataset.head()
# Out:
#    defect  outcome  peakmembership  eyear  byear            location  \
# 0     1.0        5         50000.0   1959   1956                Cuba
# 1     0.0        3          5000.0   1920   1918               Haiti
# 2     1.0        5         30000.0   1985   1985               Haiti
# 3     0.0        3           650.0   1924   1916  Dominican Republic
# 4     1.0        3             NaN   1965   1965  Dominican Republic
#
#                campaign                target  lccode  tccode  ...  lmtnest  \
# 0      Cuban Revolution        Batista regime    40.0    40.0  ...  1.69411
# 1           Caco Revolt       U.S. occupation    41.0     2.0  ...      NaN
# 2                        Jean Claude Duvalier    41.0    41.0  ...  2.79728
# 3  Dominican insurgency       U.S. occupation    42.0     2.0  ...      NaN
# 4              leftists       Loyalist regime    42.0    42.0  ...  2.85647
#
#        ef  loclpolity1  loclcap1  loclcap2  loclcap3  loclcap4    mempc  \
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 323 entries, 0 to 322
# Data columns (total 85 columns):
# defect             321 non-null float64
# outcome            323 non-null int8
# peakmembership     259 non-null float64
# eyear              323 non-null int16
# byear              323 non-null int16
# location           323 non-null object
# campaign           323 non-null object
# target             323 non-null object
# lccode             323 non-null float32
# tccode             323 non-null float32
# nonviol            323 non-null int8
# viol               323 non-null int8
# fselfdet           323 non-null int8
# regchange          323 non-null int8
# secession          323 non-null int8
# other              323 non-null int8
# success            323 non-null int8
# limited            323 non-null int8
# failure            323 non-null int8
# ongoing            323 non-null int8
# middleeast         323 non-null int8
# americas           323 non-null int8
# ...

# %%
dataset.peakmembership.value_counts().reset_index()
# Out:
#         index  peakmembership
# 0     10000.0              27
# 1    100000.0              19
# 2      5000.0              14
# 3      1000.0              14
# 4     30000.0              11
# 5     50000.0              10
# 6      3000.0              10
# 7     15000.0               9
# 8     20000.0               9
# 9     40000.0               8
# 10  1000000.0               8
# 11   200000.0               7
# 12     2000.0               7
# 13     6000.0               7
# 14     7000.0               6
# 15     2500.0               6
# 16   300000.0               5
# 17   500000.0               5
# 18     4000.0               4
# 19     1500.0               4
# 20    25000.0               3
# 21    70000.0               3
# 22    12000.0               3
# 23      400.0               3
# 24   250000.0               3
# 25    12500.0               3
# 26   400000.0               3
# 27     9000.0               2
# 28  2000000.0               2
# 29    90000.0               2
# ...

# %%
dataset.peakmembership.sum()
# Out:
# 31737016.0

# %%
dataset[dataset.peakmembership >= 500000]
# Out:
#      defect  outcome  peakmembership  eyear  byear        location  \
# 10      0.0        3       1000000.0   2006   2006          Mexico
# 38      1.0        5       1000000.0   1985   1984          Brazil
# 45      1.0        5        700000.0   1989   1983           Chile
# 75      0.0        5        500000.0   1989   1989  Czechoslovakia
# 92      0.0        5        500000.0   1963   1963          Greece
# 105     1.0        5        700000.0   1991   1990          Russia
# 113     1.0        5        500000.0   2004   2001         Ukraine
# 141     0.0        5       1000000.0   1999   1993         Nigeria
# 189     0.0        5        500000.0   2003   2002      Madagascar
# 206     1.0        5       2000000.0   1979   1977            Iran
# 228     0.0        5       1000000.0   2005   2005         Lebanon
# 255     1.0        5       1000000.0   1949   1922           China
# 257     0.0        3       4500000.0   1945   1937           China
# ...

# %%
dataset.peakmembership >= 50000
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4      False
# 5       True
# 6       True
# 7       True
# 8      False
# 9       True
# 10      True
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 293    False
# 294     True
# 295    False
# 296     True
# 297     True
# 298     True
# 299     True
# 300    False
# 301    False
# 302    False
# 303     True
# 304    False
# 305    False
# 306     True
# 307     True
# 308    False
# 309    False
# 310    False
# 311     True
# 312     True
# 313     True
# 314    False
# 315    False
# 316    False
# 317    False
# 318    False
# 319    False
# 320    False
# 321    False
# 322    False
# Name: peakmembership, Length: 323, dtype: bool

# %%
large = dataset[dataset.peakmembership >= 500000]

# %%
large.head()
# Out:
#     defect  outcome  peakmembership  eyear  byear        location  \
# 10     0.0        3       1000000.0   2006   2006          Mexico
# 38     1.0        5       1000000.0   1985   1984          Brazil
# 45     1.0        5        700000.0   1989   1983           Chile
# 75     0.0        5        500000.0   1989   1989  Czechoslovakia
# 92     0.0        5        500000.0   1963   1963          Greece
#
#              campaign             target  lccode  tccode  ...  lmtnest  \
# 10                       Calderon regime    70.0    70.0  ...      NaN
# 38         diretas ja      Military rule   140.0   140.0  ...  1.41099
# 45                      Augusto Pinochet   155.0   155.0  ...  4.07073
# 75  Velvet Revolution   Communist regime   315.0   315.0  ...  1.94591
# 92                     Karamanlis regime   350.0   350.0  ...  3.12676
#
#          ef  loclpolity1  loclcap1  loclcap2  loclcap3  loclcap4    mempc  \
# ...

# %%
large.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19 entries, 10 to 312
# Data columns (total 85 columns):
# defect             19 non-null float64
# outcome            19 non-null int8
# peakmembership     19 non-null float64
# eyear              19 non-null int16
# byear              19 non-null int16
# location           19 non-null object
# campaign           19 non-null object
# target             19 non-null object
# lccode             19 non-null float32
# tccode             19 non-null float32
# nonviol            19 non-null int8
# viol               19 non-null int8
# fselfdet           19 non-null int8
# regchange          19 non-null int8
# secession          19 non-null int8
# other              19 non-null int8
# success            19 non-null int8
# limited            19 non-null int8
# failure            19 non-null int8
# ongoing            19 non-null int8
# middleeast         19 non-null int8
# americas           19 non-null int8
# ...

# %%
amountNVCampaigns = nonviolent.nonviol.sum()

# %%
amountVCampaigns = violent.viol.sum()

# %%
amountNVCampaigns
# Out:
# 106

# %%
amountVCampaigns
# Out:
# 217

# %%
amountAllCampaigns = amountNVCampaigns + amountVCampaigns

# %%
amountAllCampaigns
# Out:
# 323

# %%
dataset.sort_values("peakmembership", ascending=False)
# Out:
#      defect  outcome  peakmembership  eyear  byear             location  \
# 257     0.0        3       4500000.0   1945   1937                China
# 206     1.0        5       2000000.0   1979   1977                 Iran
# 311     1.0        5       2000000.0   1983   1986          Philippines
# 289     0.0        3       1000000.0   1988   1988                Burma
# 265     0.0        3       1000000.0   1989   1989                China
# 262     0.0        3       1000000.0   1968   1967                China
# 255     1.0        5       1000000.0   1949   1922                China
# 10      0.0        3       1000000.0   2006   2006               Mexico
# 228     0.0        5       1000000.0   2005   2005              Lebanon
# 141     0.0        5       1000000.0   1999   1993              Nigeria
# 38      1.0        5       1000000.0   1985   1984               Brazil
# 105     1.0        5        700000.0   1991   1990               Russia
# ...

# %%
nVCampaigns = dataset[dataset.nonviol == 1]

# %%
vCampaigns = dataset[dataset.viol == 1]

# %%
nVCampaigns.sort_values("peakmembership", ascending=False).head()
# Out:
#      defect  outcome  peakmembership  eyear  byear     location  \
# 206     1.0        5       2000000.0   1979   1977         Iran
# 311     1.0        5       2000000.0   1983   1986  Philippines
# 265     0.0        3       1000000.0   1989   1989        China
# 10      0.0        3       1000000.0   2006   2006       Mexico
# 289     0.0        3       1000000.0   1988   1988        Burma
#
#                campaign             target  lccode  tccode  ...  lmtnest  \
# 206  Iranian Revolution  Shah Reza Pahlavi   630.0   630.0  ...  3.67122
# 311        People Power   Ferdinand Marcos   840.0   840.0  ...  3.10459
# 265                       Communist regime   710.0   710.0  ...  3.64806
# 10                         Calderon regime    70.0    70.0  ...      NaN
# 289    pro-dem movement     military junta   775.0   775.0  ...  3.60005
#
#           ef  loclpolity1  loclcap1  loclcap2  loclcap3  loclcap4    mempc  \
# ...

# %%
vCampaigns.sort_values("peakmembership", ascending=False).head()
# Out:
#      defect  outcome  peakmembership  eyear  byear location  \
# 257     0.0        3       4500000.0   1945   1937    China
# 262     0.0        3       1000000.0   1968   1967    China
# 255     1.0        5       1000000.0   1949   1922    China
# 103     0.0        3        400000.0   1945   1941     USSR
# 303     1.0        5        340000.0   1975   1958  Vietnam
#
#                                       campaign               target  lccode  \
# 257                             Chinese rebels  Japanese occupation   710.0
# 262                                  Red Guard         anti-Maoists   710.0
# 255                 Chinese communist movement    Kuomintang regime   710.0
# 103                         Belarus resistance      Nazi occupation   364.0
# 303  North Vietnam (National Liberation Front)      U.S. occupation   817.0
#
#      tccode  ...  lmtnest      ef  loclpolity1  loclcap1  loclcap2  loclcap3  \
# ...

# %%
dataset.sort_values("peakmembership").groupby(["nonviol", "viol"]).sum()
# Out:
#               defect  outcome  peakmembership     eyear     byear    lccode  \
# nonviol viol
# 0       1       52.0    789.0      11469116.0  426100.0  424713.0  109969.0
# 1       0       34.0    458.0      20267900.0  210129.0  209895.0   48329.0
#
#                tccode  fselfdet  regchange  secession  ...    lmtnest  \
# nonviol viol                                           ...
# 0       1     92815.0      58.0      111.0       41.0  ...  321.01984
# 1       0     46368.0      17.0       81.0        4.0  ...  149.69064
#
#                     ef  loclpolity1  loclcap1  loclcap2  loclcap3  loclcap4  \
# nonviol viol
# 0       1     63.67301       -388.0      45.0      42.0      34.0      39.0
# 1       0     30.46159       -370.0      13.0      18.0      28.0      20.0
#
#                  mempc  demdum  recur1
# nonviol viol
# 0       1     95.90069    25.0     6.0
# 1       0     71.69603    32.0     4.0
#
# [2 rows x 80 columns]

# %% [markdown]
# # How many people were in nonviolent campaigns, on average? in violent campaigns?
